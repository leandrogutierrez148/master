# %% [markdown]
# # Web Scrapping de Yuhmak
# #### Autor: Ciriondev
# #### Este documento intenta mostrar el alcance del motor de webscraping desarrollado por la empresa, para ello se utilizará la página pública de Yuhmak para extraer las motocicletas catalogadas junto con los atributos descriptivos de cada publicación.
# #### Ago 08, 2024

# %% [markdown]
# ### Extracción de datos

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import pandas as pd
import time
from selenium.common.exceptions import NoSuchElementException

if 'google.colab' in str(get_ipython()):
    options = webdriver.ChromeOptions()
    options.add_argument('-headless')
    options.add_argument('-no-sandbox')
    options.add_argument('-disable-dev-shm-usage')

    driver = webdriver.Chrome('chromedriver',options=options)

else:
    service = Service(executable_path=r'/usr/local/bin/chromedriver')
    options = webdriver.ChromeOptions()
    options.add_argument('-headless')
    options.add_argument('-no-sandbox')
    options.add_argument('-disable-dev-shm-usage')
    options.add_argument("--window-size=1920,1200")

    driver = webdriver.Chrome(service=service,options=options)

# %% [markdown]
# Definimos la URL de la sección **Motos**:

# %%
driver.get("https://www.yuhmak.com/seccion-motos/")

# %% [markdown]
# Obtenemos el listado de todas las publicaciones disponibles en la página principal de la sección:

# %%
while True:
    try:
        ver = driver.find_element(By.LINK_TEXT, 'Mostrar más')
        ver.click()
        time.sleep(3)

    except NoSuchElementException as e:
        print(f"No se encontró elemento 'Mostrar más'")
        break
# Out:
# No se encontró elemento 'Mostrar más'

# %% [markdown]
# Encontramos los links a las publicaciones:

# %%
lista = driver.find_elements(By.CSS_SELECTOR, '.vtex-search-result-3-x-galleryItem.vtex-search-result-3-x-galleryItem--normal.vtex-search-result-3-x-galleryItem--grid.pa4')

# %%
links = []

for i in range(len(lista)):
    href = lista[i].find_element(By.CSS_SELECTOR, '.vtex-product-summary-2-x-clearLink.vtex-product-summary-2-x-clearLink--product-slider.h-100.flex.flex-column')
    links.append(href.get_attribute('href'))

# %%
len(links)
# Out:
# 132

# %% [markdown]
# Procedemos a la recolección de los datos y su correspondiente análisis:

# %%
motos = pd.DataFrame()

for i in range(len(links) - 1):
        driver.get(links[i])
                
        try:
            titulo = driver.find_element(By.CLASS_NAME, 'yuhmak-yuhmak-installments-calculator-custom-0-x-productBrand ')
            tabla = driver.find_elements(By.CLASS_NAME, 'vtex-flex-layout-0-x-flexRow--productSpecificationItem')

            moto = dict({'Nombre': titulo.text})

            for i in range(len(tabla)):
                linea = tabla[i].text.split('\n')
                if len(linea) > 1:
                    atrib = linea[0]
                    valor = linea[1]
                    moto[atrib] = valor

            fila = pd.DataFrame([moto])
            motos = pd.concat([motos, fila], ignore_index=True)

        except NoSuchElementException as e:
            print(f"Error recolectando datos")
# Out:
# Error recolectando datos

# %% [markdown]
# Visualizamos la estructura de los datos obtenidos de manera dinámica:

# %%
motos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Nombre                    130 non-null    object
#  1   Modelo                    57 non-null     object
#  2   Peso                      79 non-null     object
#  3   Tipo de moto              111 non-null    object
#  4   Llantas                   64 non-null     object
#  5   Transmisión               108 non-null    object
#  6   Capacidad de combustible  106 non-null    object
#  7   Suspensión delantera      102 non-null    object
#  8   Suspensión trasera        102 non-null    object
#  9   Freno delantero           111 non-null    object
#  10  Freno trasero             111 non-null    object
#  11  Neumático delantero       91 non-null     object
#  12  Neumático trasero         91 non-null     object
#  13  Tipo de motor             108 non-null    object
#  14  Largo de moto             94 non-null     object
#  15  Ancho de moto             94 non-null     object
#  16  Alto de moto              94 non-null     object
#  17  Color                     44 non-null     object
#  18  Alimentación              73 non-null     object
#  19  Largo de caja             2 non-null      object
#  20  Ancho de caja             2 non-null      object
#  21  Alto de caja              2 non-null      object
#  22  Freno delantero Texto     15 non-null     object
#  23  Freno Trasero Texto       16 non-null     object
#  24  Garantia                  21 non-null     object
#  25  Origen                    14 non-null     object
#  26  Bloque 01                 9 non-null      object
#  27  Bloque 02                 7 non-null      object
#  28  Bloque 03                 7 non-null      object
#  29  Bloque 04                 2 non-null      object
#  30  Bloque 05                 2 non-null      object
#  31  Bloque 06                 1 non-null      object
#  32  Relación                  1 non-null      object
# dtypes: object(33)
# memory usage: 33.6+ KB

# %% [markdown]
# Veamos la forma de nuestro dataset generado mediante webscraping:

# %%
motos.shape
# Out:
# (130, 33)

# %% [markdown]
# Vemos que contamos con 130 elementos con 33 características cada uno.

# %% [markdown]
# Quitamos las columnas de nombre 'Bloque *' para facilitar la visualización de otros atributos:

# %%
pattern_to_remove = 'Bloque'

filtered_columns = [col for col in motos.columns if pattern_to_remove not in col]

# %%
motos = motos[filtered_columns]

# %% [markdown]
# Veamos un resúmen de los primeros 50 elementos recolectados

# %%
motos.head(50)
# Out:
#                                          Nombre  \
# 0                  Moto Honda Wave 110 S - 2024
# 1          Moto Honda Wave 110 Cast Disk - 2024
# 2          Moto Honda Xr 250 New Tornado - 2024
# 3               Moto Bajaj Rouser 200 Ns - 2023
# 4           Moto Motomel Blitz 110 (R/T) - 2022
# 5                    Moto Honda Xr 150 L - 2024
# 6   Moto Motomel Skua 150 Silver Edition - 2022
# 7             Moto Gilera Smash Base 110 - 2023
# 8                     Moto Benelli 180 S - 2023
# 9                   Moto Siam Qu 110 R/T - 2023
# 10                   Moto Honda Xr 190 L - 2024
# 11      Moto Bajaj Dominar 400 Ug Tourer - 2024
# 12    Moto Suzuki Ax 100 Motor 2 Tiempos - 2023
# 13       Moto Gilera Smash Tunning 110 R - 2024
# 14         Moto Corven Triax 250 Touring - 2022
# 15               Moto Gilera Gx1 125 Std - 2022
# 16        Moto Motomel Cg 150 S2 F/Disco - 2023
# 17           Moto Bajaj Rouser Ns 160 Td - 2024
# 18           Moto Motomel Dlx 110 Deluxe - 2024
# 19               Moto Bajaj Rouser N 250 - 2024
# 20                    Moto Suzuki Ax 100 - 2024
# 21                 Moto Moto Siam Qu 110 - 2024
# 22           Moto Corven Triax 150 (R/D) - 2022
# 23            Moto Gilera Smash Very 110 - 2024
# 24                 Moto Kawasaki Klx 300 - 2024
# 25               Moto Gilera Piccola 150 - 2021
# 26              Moto Corven Terrain 250X - 2020
# 27              Moto Motomel Skua 150 V6 - 2024
# 28                   Moto Benelli Tnt 15 - 2024
# 29             Moto Bajaj Dominar 250 Ug - 2024
# 30           Moto Corven Energy 110 Base - 2024
# 31              Moto Zanella Rx 150 Z7 F - 2021
# 32               Moto Kawasaki Ninja 400 - 2023
# 33                   Moto Zanella Zr 150 - 2022
# 34     Moto Zanella Styler Exclusive 150 - 2021
# 35       Moto Motomel Cg 150 S2 Base 1.8 - 2024
# 36            Moto Honda Cb 125F Twister - 2024
# 37                        Moto Cf 400 Nk - 2024
# 38              Moto Benelli Trk 251 Abs - 2023
# 39           Moto Zanella Zb 110 Z1 Base - 2024
# 40      Moto Zanella Patagonia Eagle 250 - 2022
# 41           Moto Kawasaki Ninja 400 Abs - 2024
# 42                 Moto Gilera Sahel 150 - 2025
# 43           Gilera Smash 110 Full R New - 2022
# 44               Hero X Pulse 200 On Off - 2023
# 45               Moto Zanella Due 110 Rt - 2023
# 46                    Moto Suzuki Gn 125 - 2023
# 47                     Moto Voge 650 Dsx - 2024
# 48                  Moto Motomel Xmm 250 - 2024
# 49       Moto Moto Mondial Ld 110 Max Rt - 2025
#
#                              Modelo      Peso  Tipo de moto   Llantas  \
# 0           Honda Wave 110 S - 2024    101 kg           Cub     Rayos
# 1                               NaN       NaN           NaN       NaN
# 2   Honda Xr 250 New Tornado - 2024    150 kg        ON-OFF     Rayos
# 3                               NaN    145 Kg         Naked  Aleación
# 4                               NaN     99 KG           Cub     Rayos
# 5             Honda Xr 150 L - 2024    150 kg        ON-OFF     Rayos
# 6                              2022    123 Kg        ON-OFF     Rayos
# 7                               NaN    100 kg           Cub     Rayos
# 8                               NaN    147 kg         Naked  Aleación
# 9                               NaN       NaN           NaN       NaN
# 10            Honda Xr 190 L - 2024    133 kg        ON-OFF     Rayos
# 11                              NaN       NaN       Touring       NaN
# 12                              NaN     82 kg           NaN     Rayos
# 13                    Tunning 110 R    100 Kg           Cub       NaN
# 14                Triax 250 Touring    152 kg       Touring       NaN
# 15                              NaN       NaN         Naked  Aleación
# 16                              NaN    115 kg        ON-OFF     Rayos
# 17                              NaN       NaN         Naked       NaN
# 18                              NaN       NaN           Cub       NaN
# 19        Bajaj Rouser N 250 - 2024    162 kg         Naked  Aleación
# 20                              NaN       NaN        Street       NaN
# 21                              NaN     92 kg           Cub     Rayos
# 22                             2022  125,5 kg        ON-OFF     Rayos
# 23                              NaN       NaN           Cub       NaN
# 24          Kawasaki Klx 300 - 2024  137,1 kg  Enduro-cross       NaN
# 25                             2021    100 Kg       Scooter  Aleación
# 26                    Terrain 250 X    150 kg       Atv utv       NaN
# 27                              NaN       NaN        ON-OFF       NaN
# 28                              NaN       NaN         Naked       NaN
# 29                              NaN       NaN         Naked       NaN
# 30                              NaN       NaN           Cub       NaN
# 31                             2021    113 Kg           NaN  Aleación
# 32                        Ninja 400    166 kg   Super Sport     Rayos
# 33                           ZR 150    130 Kg        ON-OFF       NaN
# 34                             2021    102 Kg           NaN  Aleación
# 35                              NaN       NaN        Street       NaN
# 36     Honda Cb 125F Twister - 2024    150 kg        Street  Aleación
# 37                        CF 400 NK    206 Kg         Naked       NaN
# 38                              NaN    176 Kg   Super Sport  Aleación
# 39                              NaN       NaN           Cub       NaN
# 40              Patagonia Eagle 250    152 Kg        Custom       NaN
# 41                              NaN       NaN   Super Sport       NaN
# 42                              NaN       NaN           NaN       NaN
# 43                             2022    101 kg           Cub  Aleación
# 44                              NaN    154 kg        Street  Aleación
# 45                              NaN     89 kg           Cub     Rayos
# 46                              NaN    105 kg        Custom  Aleación
# 47                              NaN       NaN        ON-OFF       NaN
# 48                          Xmm 250    127 Kg  Enduro-cross     Rayos
# 49                              NaN       NaN           NaN       NaN
#
#                                           Transmisión  \
# 0                                       4 velocidades
# 1                                                 NaN
# 2                                       6 velocidades
# 3                                       6 velocidades
# 4                                       4 VELOCIDADES
# 5                                       5 velocidades
# 6                                       6 velocidades
# 7               4 velocidades con embrague automático
# 8                                        Mecánica 6 v
# 9                                                 NaN
# 10                                      5 velocidades
# 11                                      6 velocidades
# 12                                      4 velocidades
# 13                                      4 Velocidades
# 14                                      6 velocidades
# 15                                             Manual
# 16                                      5 velocidades
# 17                                      6 velocidades
# 18              4 velocidades con embrague automático
# 19                                      6 Velocidades
# 20                                      4 velocidades
# 21                       Semiautomática 4 velocidades
# 22                                      6 velocidades
# 23              4 velocidades con embrague automático
# 24  6 marchas, cambio de retorno con embrague manu...
# 25                                     Automática CVT
# 26                            4 velocidades y reversa
# 27                                      5 velocidades
# 28                                      5 velocidades
# 29                                      6 velocidades
# 30                                      4 velocidades
# 31                                      5 Velocidades
# 32                                      6 velocidades
# 33                            Manual de 5 velocidades
# 34                                         Monomarcha
# 35                                      5 velocidades
# 36                                      4 velocidades
# 37                                                NaN
# 38                                             Manual
# 39                   Semi-automática de 4 velocidades
# 40                                      5 Velocidades
# 41                                      6 velocidades
# 42                                                NaN
# 43              5 velocidades con embrague automático
# 44                               Manual 5 Velocidades
# 45              4 velocidades con embrague automático
# 46                                      5 velocidades
# 47                                             Cadena
# 48                                      5 Velocidades
# 49                                                NaN
#
#    Capacidad de combustible  \
# 0                3,7 litros
# 1                       NaN
# 2               11,5 litros
# 3                 10 litros
# 4                   3,5 LTS
# 5                 12 litros
# 6               11,5 litros
# 7                4,1 litros
# 8                    10 Lts
# 9                       NaN
# 10                12 litros
# 11                13 litros
# 12                12 litros
# 13               4,1 Litros
# 14                15 Litros
# 15                      NaN
# 16                11 Litros
# 17                12 litros
# 18               3,8 litros
# 19                14 litros
# 20                12 litros
# 21                 3 Litros
# 22              12,5 litros
# 23               3,5 litros
# 24                    7,5 L
# 25                 5 litros
# 26                11 litros
# 27              11,5 litros
# 28                16 litros
# 29                     13 L
# 30                 3 litros
# 31                16 Litros
# 32                14 litros
# 33                13 Litros
# 34               5,5 Litros
# 35                11 litros
# 36              10,1 litros
# 37                17 Litros
# 38                    18 l.
# 39                 3 litros
# 40                15 Litros
# 41                14 litros
# 42                      NaN
# 43               4,1 litros
# 44                13 Litros
# 45               3,6 litros
# 46              10,5 litros
# 47                   18 lts
# 48                14 Litros
# 49                      NaN
#
#                                  Suspensión delantera  \
# 0                               Horquilla telescópica
# 1                                                 NaN
# 2                               Horquilla telescópica
# 3                 Horquilla telescópica anti fricción
# 4                               HORQUILLA HIDRA´ULICA
# 5                               Horquilla telescópica
# 6                     Horquilla telescópica invertida
# 7                               Horquilla telescópica
# 8                    Horquilla telescópica invertidas
# 9                                                 NaN
# 10                              Horquilla telescópica
# 11                Horquilla telescópica anti fricción
# 12                              Horquilla telescópica
# 13                                                NaN
# 14                   Horquilla telescópica hidráulica
# 15                     Horquilla hidráulica invertida
# 16                               Horquilla Hidráulica
# 17                              Horquilla telescópica
# 18                              Horquilla telescópica
# 19                              Horquilla telescópica
# 20                              Horquilla telescópica
# 21                                                NaN
# 22                              Horquilla telescópica
# 23                              Horquilla telescópica
# 24  Horquilla de cartucho invertido de 43 mm con a...
# 25                              Horquilla telescópica
# 26                         Amortiguadores hidráulicos
# 27                               Horquilla hidráulica
# 28                              Horquilla telescópica
# 29                                Horquilla invertida
# 30                              Horquilla telescópica
# 31                              Horquilla telescópica
# 32  Horquilla telescópica invertida con precarga a...
# 33                   Horquilla telescópica hidráulica
# 34                              Horquilla telescópica
# 35                              Horquilla telescópica
# 36                              Horquilla telescópica
# 37                              Horquilla telescópica
# 38                                Horquilla invertida
# 39                   Horquilla telescópica hidráulica
# 40                              Horquilla telescópica
# 41  Horquilla telescópica invertida con precarga a...
# 42                                                NaN
# 43                              Horquilla telescópica
# 44  Horquilla telescópica (Diam 37mm) con buje ant...
# 45                              Horquilla telescópica
# 46                              Horquilla telescópica
# 47  Horquilla invertida de 41 mm, 180 mm de recorrido
# 48                              Horquilla telescópica
# 49                                                NaN
#
#                                    Suspensión trasera  \
# 0   Basculante de doble brazo con doble amortiguad...
# 1                                                 NaN
# 2                                            Pro-Link
# 3                             Monoamortiguador Nitrox
# 4                         AMORTIGUADORES HIDRA´ULICOS
# 5                Brazo oscilante con monoamortiguador
# 6                                    Monoamortiguador
# 7                                  Doble amortiguador
# 8                                   Monoshock Central
# 9                                                 NaN
# 10               Brazo oscilante con monoamortiguador
# 11                            Monoamortiguador Nitrox
# 12                                 Doble amortiguador
# 13                                                NaN
# 14                      Doble amortiguador hidráulico
# 15                                          Monoshock
# 16                         Amortiguadores Hidráulicos
# 17                            Monoamortiguador Nitrox
# 18                                 Doble amortiguador
# 19                                   Monoamortiguador
# 20                                 Doble amortiguador
# 21                                                NaN
# 22                                   Monoamortiguador
# 23                                 Doble amortiguador
# 24  Amortiguador con carga de gas Uni-Trak® con de...
# 25                                 Doble amortiguador
# 26                                   Monoamortiguador
# 27                                   Monoamortiguador
# 28                         Monoamortiguador ajustable
# 29                        Mono shock Nitrox ajustable
# 30                                 Doble amortiguador
# 31                                 Doble amortiguador
# 32            Monoamortiguador con precarga ajustable
# 33            Doble amortiguador hidráulico regulable
# 34                                 Doble amortiguador
# 35                         Amortiguadores hidráulicos
# 36  Basculante con doble amortiguador hidráulico y...
# 37                         Monoamortiguador ajustable
# 38                                        Doble brazo
# 39                      Doble amortiguador hidráulico
# 40                                 Doble amortiguador
# 41            Monoamortiguador con precarga ajustable
# 42                                                NaN
# 43                                 Doble amortiguador
# 44                Mono Shock Ajustable a 7 Posiciones
# 45                                 Doble amortiguador
# 46  Doble amortiguador hidráulico y resorte helico...
# 47                              Monoshock con bieleta
# 48                                   Monoamortiguador
# 49                                                NaN
#
#                                       Freno delantero  ...  \
# 0                                              Tambor  ...
# 1                                                 NaN  ...
# 2                                               Disco  ...
# 3                                           Disco ABS  ...
# 4                                      TAMBOR / DISCO  ...
# 5                                               Disco  ...
# 6                                               Disco  ...
# 7                                              Tambor  ...
# 8                                     Disco Ventilado  ...
# 9                                                 NaN  ...
# 10                                              Disco  ...
# 11                                          Disco ABS  ...
# 12                                             Tambor  ...
# 13                                    Disco delantero  ...
# 14                                    Disco ventilado  ...
# 15                                              Disco  ...
# 16                                              Disco  ...
# 17                                              Disco  ...
# 18                                             Tambor  ...
# 19                                    Disco delantero  ...
# 20                                             Tambor  ...
# 21                                             Tambor  ...
# 22                                              Disco  ...
# 23                                             Tambor  ...
# 24  Disco lobulado simple de 250 mm con pinza de d...  ...
# 25                                              Disco  ...
# 26                                              Disco  ...
# 27                                              Disco  ...
# 28                                              Disco  ...
# 29                       300 mm ABS doble canal disco  ...
# 30                                             Tambor  ...
# 31                                              Disco  ...
# 32                                          Disco ABS  ...
# 33                                    Disco delantero  ...
# 34                                              Disco  ...
# 35                                             Tambor  ...
# 36                                              Disco  ...
# 37                                                ABS  ...
# 38                                           Un disco  ...
# 39                                             Tambor  ...
# 40                                    Disco delantero  ...
# 41                                          Disco ABS  ...
# 42                                                NaN  ...
# 43                                              Disco  ...
# 44                          Disco de 276 mm Diam. ABS  ...
# 45                                             Tambor  ...
# 46                                              Disco  ...
# 47  Doble disco 298 mm, pinzas de 2 pistones NISSI...  ...
# 48                                    Disco delantero  ...
# 49                                                NaN  ...
#
#                   Color                              Alimentación  \
# 0                   NaN                                       NaN
# 1                   NaN                                       NaN
# 2                   NaN                                       NaN
# 3                 Negro                     Inyección electrónica
# 4           BlancoNegro                                       NaN
# 5                   NaN                                       NaN
# 6                  Gris                                Carburador
# 7                  Rojo                                Carburador
# 8       BlancoNegroRojo                                       NaN
# 9                   NaN                                       NaN
# 10                  NaN                                       NaN
# 11                  NaN                     Inyección electrónica
# 12    NegroRojoAzulGris                                Carburador
# 13                  NaN                                Carburador
